# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Question 7

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0f64dea4-9447-4547-9e5f-a17df8681277" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0f64dea4-9447-4547-9e5f-a17df8681277">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("Q7.csv")

# %%
data
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0             Mazda RX4    3.90  2.620  16.46
# 1         Mazda RX4 Wag    3.90  2.875  17.02
# 2            Datsun 710    3.85  2.320  18.61
# 3        Hornet 4 Drive    3.08  3.215  19.44
# 4     Hornet Sportabout    3.15  3.440  17.02
# 5               Valiant    2.76  3.460  20.22
# 6            Duster 360    3.21  3.570  15.84
# 7             Merc 240D    3.69  3.190  20.00
# 8              Merc 230    3.92  3.150  22.90
# 9              Merc 280    3.92  3.440  18.30
# 10            Merc 280C    3.92  3.440  18.90
# 11           Merc 450SE    3.07  4.070  17.40
# 12           Merc 450SL    3.07  3.730  17.60
# 13          Merc 450SLC    3.07  3.780  18.00
# 14   Cadillac Fleetwood    2.93  5.250  17.98
# 15  Lincoln Continental    3.00  5.424  17.82
# 16    Chrysler Imperial    3.23  5.345  17.42
# 17             Fiat 128    4.08  2.200  19.47
# 18          Honda Civic    4.93  1.615  18.52
# ...

# %%
data.mean()
# Out:
# <ipython-input-8-abc01cf6c622>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# Points     3.596563
# Score      3.217250
# Weigh     17.848750
# dtype: float64

# %%
data.median()
# Out:
# <ipython-input-9-135339ac59ce>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# Points     3.695
# Score      3.325
# Weigh     17.710
# dtype: float64

# %%
data.mode()
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0           AMC Javelin    3.07   3.44  17.02
# 1    Cadillac Fleetwood    3.92    NaN  18.90
# 2            Camaro Z28     NaN    NaN    NaN
# 3     Chrysler Imperial     NaN    NaN    NaN
# 4            Datsun 710     NaN    NaN    NaN
# 5      Dodge Challenger     NaN    NaN    NaN
# 6            Duster 360     NaN    NaN    NaN
# 7          Ferrari Dino     NaN    NaN    NaN
# 8              Fiat 128     NaN    NaN    NaN
# 9             Fiat X1-9     NaN    NaN    NaN
# 10       Ford Pantera L     NaN    NaN    NaN
# 11          Honda Civic     NaN    NaN    NaN
# 12       Hornet 4 Drive     NaN    NaN    NaN
# 13    Hornet Sportabout     NaN    NaN    NaN
# 14  Lincoln Continental     NaN    NaN    NaN
# 15         Lotus Europa     NaN    NaN    NaN
# 16        Maserati Bora     NaN    NaN    NaN
# 17            Mazda RX4     NaN    NaN    NaN
# 18        Mazda RX4 Wag     NaN    NaN    NaN
# ...

# %%
data.std()
# Out:
# <ipython-input-13-a47ac8255c06>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.std()
# Points    0.534679
# Score     0.978457
# Weigh     1.786943
# dtype: float64

# %%
data.var()
# Out:
# <ipython-input-16-6bf595b3cfe5>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.var()
# Points    0.285881
# Score     0.957379
# Weigh     3.193166
# dtype: float64

# %%
data.describe()
# Out:
#           Points      Score      Weigh
# count  32.000000  32.000000  32.000000
# mean    3.596563   3.217250  17.848750
# std     0.534679   0.978457   1.786943
# min     2.760000   1.513000  14.500000
# 25%     3.080000   2.581250  16.892500
# 50%     3.695000   3.325000  17.710000
# 75%     3.920000   3.610000  18.900000
# max     4.930000   5.424000  22.900000

# %% [markdown]
# ### Question 9

# %%
import matplotlib.pyplot as plt
from scipy.stats import kurtosis,skew

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-045bd22b-208a-4617-8ded-ef2483648dd8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-045bd22b-208a-4617-8ded-ef2483648dd8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-3f32d4d6-cb83-4d8e-b1a2-5eb38618b641" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f32d4d6-cb83-4d8e-b1a2-5eb38618b641">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data1 = pd.read_csv("Q9_a.csv")

# %%
data2 = pd.read_csv("Q9_b.csv")

# %%
data1.head()
# Out:
#    Index  speed  dist
# 0      1      4     2
# 1      2      4    10
# 2      3      7     4
# 3      4      7    22
# 4      5      8    16

# %%
data1.skew()
# Out:
# Index    0.000000
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
data1.kurt()
# Out:
# Index   -1.200000
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
speed_skew=data1['speed'].skew()
speed_skew
# Out:
# -0.11750986144663393

# %%
dist_kurt=data1['dist'].kurt()
dist_kurt
# Out:
# 0.4050525816795765

# %%
speed_kurt=data1['speed'].kurt()
speed_kurt
# Out:
# -0.5089944204057617

# %% [markdown]
# ### Question 9 B

# %%
data2 = pd.read_csv('Q9_b.csv')

# %%
data2
# Out:
#     Unnamed: 0          SP         WT
# 0            1  104.185353  28.762059
# 1            2  105.461264  30.466833
# 2            3  105.461264  30.193597
# 3            4  113.461264  30.632114
# 4            5  104.461264  29.889149
# ..         ...         ...        ...
# 76          77  169.598513  16.132947
# 77          78  150.576579  37.923113
# 78          79  151.598513  15.769625
# 79          80  167.944460  39.423099
# 80          81  139.840817  34.948615
#
# [81 rows x 3 columns]

# %%
data2['SP'].skew()
# Out:
# 1.6114501961773586

# %%
data2['WT'].skew()
# Out:
# -0.6147533255357768

# %%
data2['SP'].kurt()
# Out:
# 2.9773289437871835

# %%
data2['WT'].kurt()
# Out:
# 0.9502914910300326

# %% [markdown]
# ### Question 20

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-555ac325-503b-4443-a570-a8b16e3f3daa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-555ac325-503b-4443-a570-a8b16e3f3daa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
cars = pd.read_csv('Cars.csv')

# %%
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %% [markdown]
# MPG data into Dataframe

# %%
from tables import Column
cars = pd.DataFrame(cars,columns=['MPG'])

# %%
cars
# Out:
#           MPG
# 0   53.700681
# 1   50.013401
# 2   50.013401
# 3   45.696322
# 4   50.504232
# ..        ...
# 76  36.900000
# 77  19.197888
# 78  34.000000
# 79  19.833733
# 80  12.101263
#
# [81 rows x 1 columns]

# %% [markdown]
# ## Description of Data of MPG

# %%
cars.describe()
# Out:
#              MPG
# count  81.000000
# mean   34.422076
# std     9.131445
# min    12.101263
# 25%    27.856252
# 50%    35.152727
# 75%    39.531633
# max    53.700681

# %% [markdown]
# ### a.P(MPG>38)

# %%
from scipy import stats

# %%
1-stats.norm.cdf(38,34.420076,9.131445)
# Out:
# 0.3475130226138622

# %% [markdown]
# Here the probability of area >38 is 34.75

# %% [markdown]
# ### b. P(MPG<40)

# %%
stats.norm.cdf(40,34.422076,9.131445)
# Out:
# 0.7293498604157946

# %% [markdown]
# Here the probability of area<40 is 72.93%

# %% [markdown]
# ## c.P(20<MPG<50)

# %%
a= stats.norm.cdf(50,34.422076,9.131445)

# %%
b= stats.norm.cdf(20,34.422076,9.131445)

# %%
a-b
# Out:
# 0.8988689076273199

# %% [markdown]
# From above calculation we can find the probabilty of area between 20 and 50 is 89.88%

# %% [markdown]
# ### Quetion No 21 (A)

# %%
import matplotlib.pyplot as plt

# %%
cars.describe()
# Out:
#              MPG
# count  81.000000
# mean   34.422076
# std     9.131445
# min    12.101263
# 25%    27.856252
# 50%    35.152727
# 75%    39.531633
# max    53.700681

# %%
plt.title('MPG Distribution')
plt.hist(cars,color='blue')
plt.xlabel('Index')
plt.ylabel('MPG')
plt.show()

# %% [markdown]
# ### Inference

# %% [markdown]
# From the above histrogram plot it appears that mean and median values of MPG is 34.422076 and 35.152727 resspectively which is very close to each other. So we can say that the data is normally distributed. It also appers it is slightly left skewed but it has bell curve so it is normal distribution.

# %% [markdown]
# ### Question No-21 (B)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bc3cf8bb-7e8c-46ff-9586-60c0b29f7246" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bc3cf8bb-7e8c-46ff-9586-60c0b29f7246">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Body = pd.read_csv('wc-at.csv')

# %%
Body
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
Body_1 = pd.DataFrame(Body, columns=['AT'])

# %%
Body_1
# Out:
#          AT
# 0     25.72
# 1     25.89
# 2     42.60
# 3     42.80
# 4     29.84
# ..      ...
# 104  124.00
# 105   62.20
# 106  133.00
# 107  208.00
# 108  208.00
#
# [109 rows x 1 columns]

# %%
Body_2= pd.DataFrame(Body, columns=['Waist'])
Body_2
# Out:
#       Waist
# 0     74.75
# 1     72.60
# 2     81.80
# 3     83.95
# 4     74.65
# ..      ...
# 104  100.10
# 105   93.30
# 106  101.80
# 107  107.90
# 108  108.50
#
# [109 rows x 1 columns]

# %%
plt.title('AT distibution')
plt.hist(Body_1, color='Green')
plt.xlabel('Index')
plt.ylabel('AT')
plt.show()

# %% [markdown]
# ## Infrence
# For AT from the graph we can clearly see that it is right skeweddistribution as many data lies on the right side of the plot, hence it is not normally distributed

# %%
plt.title('Waist Distribution')
plt.hist(Body_2, color="blue")
plt.xlabel('Index')
plt.ylabel('Waist')
plt.show()

# %% [markdown]
# ## Inference
# Form the above graph for WT we can observe that it has two peaks and it has binomial distribution, so we can say that the data is not normally distributed

# %% [markdown]
# ## Question No 22

# %%
confidence_level = 0.90
zscore_90 = stats.norm.ppf(1-(1-confidence_level)/2)
zscore_90
# Out:
# 1.6448536269514722

# %% [markdown]
# For 90% confidence level the Z-score is 1.64

# %% [markdown]
# For 94% confidnece level, Zscore

# %%
confidence_level = 0.94
zscore_94 = stats.norm.ppf(1-(1-confidence_level)/2)
zscore_94
# Out:
# 1.8807936081512509

# %% [markdown]
# For 94% confidence level the Z-score is 1.88

# %% [markdown]
# For 60% confidence level , Z score

# %%
confidence_level= 0.60
zscore_60 = stats.norm.ppf(1-(1-confidence_level)/2)
zscore_60
# Out:
# 0.8416212335729143

# %% [markdown]
# For 60% confidence level the Z-score is 0.84

# %% [markdown]
# # Question No 23

# %% [markdown]
# T- Score

# %%
# Degree of freedom = 24 since sample size is 25

# %% [markdown]
# For 95% confidence level T-Score

# %%
confidence_level=0.99
t_score99=stats.t.ppf(1-(1-confidence_level)/2, df=24)
t_score99
# Out:
# 2.796939504772804

# %% [markdown]
# # Question No 24

# %%
# From the question number 24
Population_mean= 270
Sample_size = 18
Sample_mean = 260
sample_Std_dev= 90
alpha= 0.05

# %% [markdown]
# T-value

# %%
std_error=sample_Std_dev/np.sqrt(Sample_size)
t_value= (Sample_mean-Population_mean)/std_error
t_value
# Out:
# -0.4714045207910317

# %%
p_value= stats.t.cdf(t_value, df=17)
p_value
# Out:
# 0.32167253567098364

# %%
if (p_value>alpha):
  print("The company's claim is not acepted")
else:
  print("The company's claim is  acepted")
# Out:
# The company's claim is not acepted

# %% [markdown]
# # Inference
# Since the confidence interval is not given we assume it as 95% and alpha = 0.05. Also since std dev of sample is not given the t-value is 0.471 and p-value is 0.321. We consider this as degree of freedom is 17. Here P > alpha. The null hypothesis is accepted and the average bulb last for 270 days
